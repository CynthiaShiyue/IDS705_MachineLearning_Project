# %%
import pandas as pd

# %%
data = pd.read_csv("California_Fire_Perimeters_(all).csv")
#https://data.ca.gov/dataset/california-fire-perimeters-all

data=data[data["STATE"]=="CA"]
data=data[data["OBJECTIVE"]==1] # wire fire

data
# Out:
#        OBJECTID   YEAR_ STATE AGENCY UNIT_ID  FIRE_NAME   INC_NUM  \
# 0             1  2023.0    CA    CDF     SKU  WHITWORTH  00004808
# 1             2  2023.0    CA    LRA     BTU     KAISER  00010225
# 2             3  2023.0    CA    CDF     AEU    JACKSON  00017640
# 3             4  2023.0    CA    CDF     AEU     CARBON  00018821
# 4             5  2023.0    CA    CDF     AEU    LIBERTY  00018876
# ...         ...     ...   ...    ...     ...        ...       ...
# 22256     22257     NaN    CA    CCO     MRN     UKNOWN       NaN
# 22257     22258     NaN    CA    CCO     MRN     UKNOWN       NaN
# 22258     22259     NaN    CA    CCO     MRN     UKNOWN       NaN
# 22259     22260     NaN    CA    CCO     MRN     UKNOWN       NaN
# 22260     22261     NaN    CA    CCO     MRN     UKNOWN       NaN
#
#                    ALARM_DATE               CONT_DATE  CAUSE  ...  OBJECTIVE  \
# 0      2023/06/17 00:00:00+00  2023/06/17 00:00:00+00    5.0  ...        1.0
# ...

# %%
data2=pd.read_csv("California_County_Boundaries.csv")
data2
# Out:
#     OBJECTID  COUNTY_NAME COUNTY_ABBREV  COUNTY_NUM  COUNTY_CODE  COUNTY_FIPS  \
# 0          1      Alameda           ALA           1            1            1
# 1          2       Alpine           ALP           2            2            3
# 2          3       Amador           AMA           3            3            5
# 3          4        Butte           BUT           4            4            7
# 4          5    Calaveras           CAL           5            5            9
# ..       ...          ...           ...         ...          ...          ...
# 64        65      Ventura           VEN          56           56          111
# 65        66      Ventura           VEN          56           56          111
# 66        67      Ventura           VEN          56           56          111
# 67        68  Los Angeles           LOS          19           19           37
# 68        69  Los Angeles           LOS          19           19           37
#
# ...

# %%
import geopandas as gpd

gdf = gpd.read_file("POSTFIRE_MASTER_DATA_SHARE.geojson", engine="fiona")
#from https://www.kaggle.com/datasets/vijayveersingh/the-california-wildfire-data/data


#fire23_1 from cal fire original dataset2 
print(gdf.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import geopandas as gpd
#       3 gdf = gpd.read_file("POSTFIRE_MASTER_DATA_SHARE.geojson", engine="fiona")
#       4 #from https://www.kaggle.com/datasets/vijayveersingh/the-california-wildfire-data/data
#       5
#       6
#       7 #fire23_1 from cal fire original dataset2
#
# ModuleNotFoundError: No module named 'geopandas'
