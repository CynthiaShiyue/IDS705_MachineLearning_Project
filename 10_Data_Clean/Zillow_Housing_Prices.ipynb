# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.set_option("mode.copy_on_write", True)

# %%
# Step 1: Get single family index from zillow per zip code

zillow_link = "https://files.zillowstatic.com/research/public_csvs/zhvi/Zip_zhvi_uc_sfr_tier_0.33_0.67_sm_sa_month.csv?t=1744845404"

# Step 2: Read the data and explore

zillow_data = pd.read_csv(zillow_link) # insert your path
zillow_data.info()
zillow_data.head(5)
# Out:
#   Cell In[5], line 1
#     link =
#            ^
# SyntaxError: invalid syntax
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     91982         1       77494        zip        TX    TX      Katy
# 1     61148         2        8701        zip        NJ    NJ  Lakewood
# 2     91940         3       77449        zip        TX    TX      Katy
# 3     62080         4       11368        zip        NY    NY  New York
# 4     91733         5       77084        zip        TX    TX   Houston
#
#                                    Metro        CountyName     2000-01-31  \
# 0   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  212578.371658
# 1  New York-Newark-Jersey City, NY-NJ-PA      Ocean County  157063.441610
# 2   Houston-The Woodlands-Sugar Land, TX     Harris County  104837.094005
# 3  New York-Newark-Jersey City, NY-NJ-PA     Queens County  302826.826552
# 4   Houston-The Woodlands-Sugar Land, TX     Harris County  103964.199279
#
# ...

# %%
# Step 3: Rename region name by region zip code to avoid confusion
zillow_data.rename(columns={'RegionName': 'ZipCode'}, inplace=True)

# Step 4: Substet for California state
cali_data = zillow_data.loc[zillow_data["StateName"] == "CA"]

# %%
# Step 5: Subset post crisis 2010 - 2022
subset_date = cali_data.loc[:, cali_data.columns.str.match(r'^(201[0-9]|202[0-2])-\d{2}-\d{2}$')]

# Include all other columns (like RegionID, Zip_Code, etc.)
other_cols = ['RegionID', 'SizeRank', 'ZipCode', 'RegionType', 'StateName', 'State', 'City', 'Metro', 'CountyName']

cali_2010_2022 = cali_data[other_cols + list(subset_date.columns)]

cali_2010_2022.head(5) #print
# Out:
#     RegionID  SizeRank  ZipCode RegionType StateName State         City  \
# 9      95992        10    90011        zip        CA    CA  Los Angeles
# 12     96193        13    90650        zip        CA    CA      Norwalk
# 13     96361        14    91331        zip        CA    CA  Los Angeles
# 21     96025        22    90044        zip        CA    CA  Los Angeles
# 22     96817        23    92336        zip        CA    CA      Fontana
#
#                                    Metro             CountyName  \
# 9     Los Angeles-Long Beach-Anaheim, CA     Los Angeles County
# 12    Los Angeles-Long Beach-Anaheim, CA     Los Angeles County
# 13    Los Angeles-Long Beach-Anaheim, CA     Los Angeles County
# 21    Los Angeles-Long Beach-Anaheim, CA     Los Angeles County
# 22  Riverside-San Bernardino-Ontario, CA  San Bernardino County
#
#        2010-01-31  ...     2022-03-31     2022-04-30     2022-05-31  \
# 9   167671.452412  ...  560637.777922  564074.897440  567304.613387
# ...
