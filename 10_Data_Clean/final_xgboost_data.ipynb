# %%
import pandas as pd

# %%
# Load the saved datasets
final_fire_data = pd.read_csv("final_fire_data.csv")
final_home_price = pd.read_csv("final_home_price.csv")

# %%
# Convert ZIP code to string and pad if needed
final_fire_data["ZIP_CODE"] = final_fire_data["ZIP_CODE"].astype(str).str.zfill(5)
final_home_price["ZipCode"] = final_home_price["ZipCode"].astype(str).str.zfill(5)

# Convert year to int (if needed)
final_fire_data["YEAR_"] = final_fire_data["YEAR_"].astype(int)
final_home_price["YEAR"] = final_home_price["YEAR"].astype(int)

# %%
final_fire_data.shape
# Out:
# (1917, 7)

# %%
merged_data = pd.merge(
    final_home_price,
    final_fire_data,
    left_on=["ZipCode", "YEAR"],
    right_on=["ZIP_CODE", "YEAR_"],
    how="left",
    indicator=True
)

merged_data["_merge"].value_counts()
# Out:
# _merge
# left_only     8750
# both          1380
# right_only       0
# Name: count, dtype: int64

# %%
# Those are the ZIPs that aren’t included in Zillow’s home price data.

unmatched_zips = final_fire_data.loc[
    ~final_fire_data["ZIP_CODE"].isin(final_home_price["ZipCode"].unique()),
    "ZIP_CODE"
].value_counts()

unmatched_zips.head # 77 zips aren't included in zillow dataset

# there's 196 (1917 - 1721) fire that did not match because zillow does not include 77 zip codes
# those 77 ZIPs’ rows in the fire data are dropped in the final merge result, because we're joining from Zillow’s ZIPs only (left join), and those 77 ZIPs don’t exist there.
# Out:
# <bound method NDFrame.head of ZIP_CODE
# 95568    8
# 95043    7
# 96108    7
# 93633    7
# 93563    7
#         ..
# 95372    1
# 95317    1
# 93628    1
# 96033    1
# 95552    1
# Name: count, Length: 100, dtype: int64>

# %%
# Create a flag column for fire exposure
# 0 means no
# 1 means yes
merged_data["FIRE_EXPOSED"] = (merged_data["_merge"] == "both").astype(int)

# Drop merge indicator and other useless columns
col_drop = ["_merge", "ZIP_CODE", "YEAR_", "NEXT_YEAR_PRICE"]
merged_data.drop(columns=col_drop, inplace=True)

merged_data
# Out:
#       ZipCode  YEAR  RegionID             City  \
# 0       90001  2012     95982  Florence-Graham
# 1       90001  2013     95982  Florence-Graham
# 2       90001  2014     95982  Florence-Graham
# 3       90001  2015     95982  Florence-Graham
# 4       90001  2016     95982  Florence-Graham
# ...       ...   ...       ...              ...
# 10125   96161  2014     98672          Truckee
# 10126   96161  2015     98672          Truckee
# 10127   96161  2016     98672          Truckee
# 10128   96161  2017     98672          Truckee
# 10129   96161  2018     98672          Truckee
#
#                                     Metro          CountyName     HOME_PRICE  \
# 0      Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  173120.150950
# 1      Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  213862.137082
# 2      Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  250721.453550
# 3      Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  255205.837249
# 4      Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  280380.216244
# ...                                   ...                 ...            ...
# 10125            Truckee-Grass Valley, CA       Nevada County  550710.293321
# 10126            Truckee-Grass Valley, CA       Nevada County  568621.894253
# 10127            Truckee-Grass Valley, CA       Nevada County  598426.143553
# 10128            Truckee-Grass Valley, CA       Nevada County  643972.995049
# 10129            Truckee-Grass Valley, CA       Nevada County  680366.250903
#
#        PRICE_CHANGE  PCT_PRICE_CHANGE (%)  NUM_FIRES  \
# 0      40741.986132             23.533936        NaN
# 1      36859.316468             17.235083        NaN
# 2       4484.383699              1.788592        NaN
# 3      25174.378994              9.864343        NaN
# 4      51139.857090             18.239467        NaN
# ...             ...                   ...        ...
# 10125  17911.600932              3.252454        NaN
# 10126  29804.249300              5.241488        NaN
# 10127  45546.851495              7.611107        NaN
# 10128  36393.255854              5.651364        NaN
# 10129   7083.785644              1.041172        NaN
#
#        TOTAL_ACRES_BURNED_IN_ZIP  AVG_FIRE_DURATION_DAYS  MAX_PCT_ZIP_BURNED  \
# 0                            NaN                     NaN                 NaN
# 1                            NaN                     NaN                 NaN
# 2                            NaN                     NaN                 NaN
# 3                            NaN                     NaN                 NaN
# 4                            NaN                     NaN                 NaN
# ...                          ...                     ...                 ...
# 10125                        NaN                     NaN                 NaN
# 10126                        NaN                     NaN                 NaN
# 10127                        NaN                     NaN                 NaN
# 10128                        NaN                     NaN                 NaN
# 10129                        NaN                     NaN                 NaN
#
#        ANY_MAJOR_FIRE  FIRE_EXPOSED
# 0                 NaN             0
# 1                 NaN             0
# 2                 NaN             0
# 3                 NaN             0
# 4                 NaN             0
# ...               ...           ...
# 10125             NaN             0
# 10126             NaN             0
# 10127             NaN             0
# 10128             NaN             0
# 10129             NaN             0
#
# [10130 rows x 15 columns]

# %%
oo = merged_data.loc[merged_data["FIRE_EXPOSED"] == 1]
oo.head(20)
# Out:
#     ZipCode  YEAR  RegionID         City                               Metro  \
# 143   90027  2015     96008  Los Angeles  Los Angeles-Long Beach-Anaheim, CA
# 287   90049  2012     96030  Los Angeles  Los Angeles-Long Beach-Anaheim, CA
# 290   90049  2015     96030  Los Angeles  Los Angeles-Long Beach-Anaheim, CA
# 292   90049  2017     96030  Los Angeles  Los Angeles-Long Beach-Anaheim, CA
# 382   90077  2012     96058  Los Angeles  Los Angeles-Long Beach-Anaheim, CA
# 387   90077  2017     96058  Los Angeles  Los Angeles-Long Beach-Anaheim, CA
# 543   90265  2012     96116       Malibu  Los Angeles-Long Beach-Anaheim, CA
# 544   90265  2013     96116       Malibu  Los Angeles-Long Beach-Anaheim, CA
# 545   90265  2014     96116       Malibu  Los Angeles-Long Beach-Anaheim, CA
# 546   90265  2015     96116       Malibu  Los Angeles-Long Beach-Anaheim, CA
# 547   90265  2016     96116       Malibu  Los Angeles-Long Beach-Anaheim, CA
# 548   90265  2017     96116       Malibu  Los Angeles-Long Beach-Anaheim, CA
# 549   90265  2018     96116       Malibu  Los Angeles-Long Beach-Anaheim, CA
# 564   90272  2012     96120  Los Angeles  Los Angeles-Long Beach-Anaheim, CA
# 566   90272  2014     96120  Los Angeles  Los Angeles-Long Beach-Anaheim, CA
# 567   90272  2015     96120  Los Angeles  Los Angeles-Long Beach-Anaheim, CA
# 607   90290  2013     96126      Topanga  Los Angeles-Long Beach-Anaheim, CA
# 608   90290  2014     96126      Topanga  Los Angeles-Long Beach-Anaheim, CA
# 609   90290  2015     96126      Topanga  Los Angeles-Long Beach-Anaheim, CA
# 610   90290  2016     96126      Topanga  Los Angeles-Long Beach-Anaheim, CA
#
#              CountyName    HOME_PRICE   PRICE_CHANGE  PCT_PRICE_CHANGE (%)  \
# 143  Los Angeles County  1.057405e+06   61864.537331              5.850597
# 287  Los Angeles County  1.642617e+06  311152.007681             18.942452
# 290  Los Angeles County  1.880899e+06  105512.747439              5.609697
# 292  Los Angeles County  2.479988e+06  716128.067841             28.876269
# 382  Los Angeles County  1.307452e+06  228485.992941             17.475671
# 387  Los Angeles County  2.009354e+06  486641.126398             24.218784
# 543  Los Angeles County  1.468093e+06  186187.083919             12.682241
# 544  Los Angeles County  1.654280e+06  185283.917682             11.200275
# 545  Los Angeles County  1.839564e+06 -196879.647731            -10.702517
# 546  Los Angeles County  1.642684e+06  129122.680928              7.860468
# 547  Los Angeles County  1.771807e+06  495677.095984             27.975795
# 548  Los Angeles County  2.267484e+06  706927.241031             31.176723
# 549  Los Angeles County  2.974411e+06 -163883.012371             -5.509763
# 564  Los Angeles County  1.643528e+06  294303.013632             17.906780
# 566  Los Angeles County  2.165553e+06 -243328.756211            -11.236331
# 567  Los Angeles County  1.922225e+06  102003.005493              5.306508
# 607  Los Angeles County  7.690747e+05   72151.995109              9.381663
# 608  Los Angeles County  8.412267e+05  -50665.882575             -6.022857
# 609  Los Angeles County  7.905608e+05   19937.546419              2.521950
# 610  Los Angeles County  8.104984e+05  106548.101006             13.145998
#
#      NUM_FIRES  TOTAL_ACRES_BURNED_IN_ZIP  AVG_FIRE_DURATION_DAYS  \
# 143        1.0                   4.730200                     0.0
# 287        1.0                  39.644336                     1.0
# 290        1.0                   0.251434                     NaN
# 292        1.0                 243.229969                     9.0
# 382        1.0                  13.878707                     1.0
# 387        1.0                 176.690177                     9.0
# 543        1.0                   1.005463                     0.0
# 544        2.0                1889.624969                     4.5
# 545        9.0                   2.579399                     0.0
# 546        7.0                  12.945944                     0.0
# 547        3.0                  13.077714                     1.0
# 548        3.0                  22.705719                     1.0
# 549        4.0               40808.925333                     3.5
# 564        1.0                   6.449685                     0.0
# 566        1.0                   3.024881                     0.0
# 567        1.0                   1.193674                     0.0
# 607        1.0                   0.085204                     0.0
# 608        2.0                   3.072061                     0.0
# 609        2.0                   0.345340                     0.0
# 610        2.0                 200.612728                     2.0
#
#      MAX_PCT_ZIP_BURNED  ANY_MAJOR_FIRE  FIRE_EXPOSED
# 143            0.089696             0.0             1
# 287            0.412962             0.0             1
# 290            0.002619             0.0             1
# 292            2.533646             0.0             1
# 382            0.291472             0.0             1
# 387            3.710731             0.0             1
# 543            0.001662             0.0             1
# 544            3.122382             0.0             1
# 545            0.001309             0.0             1
# 546            0.008914             0.0             1
# 547            0.018720             0.0             1
# 548            0.033059             0.0             1
# 549           67.447315             1.0             1
# 564            0.040718             0.0             1
# 566            0.019096             0.0             1
# 567            0.007536             0.0             1
# 607            0.000716             0.0             1
# 608            0.025022             0.0             1
# 609            0.002112             0.0             1
# 610            1.678439             0.0             1

# %%
# FINAL XGBOOST DATA

Xgboost_data = merged_data.copy()
